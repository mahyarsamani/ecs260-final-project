# %%
import pandas as pd  # To read data
import matplotlib.pyplot as plt
from pandas.plotting import table 

# Reference: https://www.learndatasci.com/tutorials/predicting-housing-prices-linear-regression-using-python-pandas-statsmodels/
from IPython.core.display import HTML, display
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
## Load data from csv as dataframe and process data
df_csv = pd.read_csv('metrics_dummydata.csv')

num_commits_mean = df_csv["Num_commits"].mean()
num_commits_median = df_csv["Num_commits"].median()

num_bugs_mean = df_csv["Num_bugs"].mean()
num_bugs_median = df_csv["Num_bugs"].median()

PR_opened_mean = df_csv["PR_opened"].mean()
PR_opened_median = df_csv["PR_opened"].median()

PR_closed_mean = df_csv["PR_closed"].mean()
PR_closed_median = df_csv["PR_closed"].median()

PR_merged_mean = df_csv["PR_merged"].mean()
PR_merged_median = df_csv["PR_merged"].median()

PR_unmerged_mean = df_csv["PR_unmerged"].mean()
PR_unmerged_median = df_csv["PR_unmerged"].median()

# %%
## Create table
data = {'Metrics':['num_commits','num_bugs','num_PRopened','num_PRclosed','num_PRmerged','num_PRunmerged'],
        'Description':['Total number of commits per repository','Total number of bugs and/or issues after each project release',
                        'Total number of opened pull requests per repository','Total number of closed pull requests per repository',
                        'Total number of merged pull requests per repository','Total number of unmerged pull requests per repository'],
        'Mean':[num_commits_mean, num_bugs_mean, PR_opened_mean, PR_closed_mean, PR_merged_mean, PR_unmerged_mean],
        'Median':[num_commits_median, num_commits_median, PR_opened_median, PR_closed_median, PR_merged_median, PR_unmerged_median]}

df = pd.DataFrame(data)
df.style.set_properties(**{'text-align': 'left'})

print(df)
# Out:
#           Metrics                                        Description   Mean  \
# 0     num_commits             Total number of commits per repository  55.90
# 1        num_bugs  Total number of bugs and/or issues after each ...  47.15
# 2    num_PRopened  Total number of opened pull requests per repos...  38.45
# 3    num_PRclosed  Total number of closed pull requests per repos...  50.20
# 4    num_PRmerged  Total number of merged pull requests per repos...  40.95
# 5  num_PRunmerged  Total number of unmerged pull requests per rep...  38.40
#
#    Median
# 0    58.5
# 1    58.5
# 2    30.5
# 3    51.5
# 4    36.5
# 5    31.0

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(641, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

tb = table(ax, df, loc='left',colWidths=[1, 3, 0.4, 0.4])  # where df is your data frame
tb.auto_set_font_size(False)
tb.set_fontsize(14)
tb.scale(1,6)
plt.savefig('metrics_table.png', bbox_inches='tight', pad_inches=0.1)

# %%
## Load data from csv as dataframe and process data
df_csv = pd.read_csv('metrics_dummydata.csv')
# print(df_csv)

productivity_performance_model = ols("Num_commits ~ Num_bugs", data=df_csv).fit()
productivity_performance_model_summary = productivity_performance_model.summary()
display(HTML(
(productivity_performance_model_summary.as_html())))
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>       <td>Num_commits</td>   <th>  R-squared:         </th> <td>   0.000</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>  -0.055</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>0.005159</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Wed, 10 Nov 2021</td> <th>  Prob (F-statistic):</th>  <td> 0.944</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>18:36:05</td>     <th>  Log-Likelihood:    </th> <td> -94.744</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>    20</td>      <th>  AIC:               </th> <td>   193.5</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>    18</td>      <th>  BIC:               </th> <td>   195.5</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     1</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   55.0425</td> <td>   13.598</td> <td>    4.048</td> <td> 0.001</td> <td>   26.474</td> <td>   83.611</td>
# </tr>
# <tr>
#   <th>Num_bugs</th>  <td>    0.0182</td> <td>    0.253</td> <td>    0.072</td> <td> 0.944</td> <td>   -0.514</td> <td>    0.550</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td> 2.804</td> <th>  Durbin-Watson:     </th> <td>   1.167</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.246</td> <th>  Jarque-Bera (JB):  </th> <td>   1.192</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td> 0.009</td> <th>  Prob(JB):          </th> <td>   0.551</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 1.804</td> <th>  Cond. No.          </th> <td>    112.</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
